# %%
#Creates a custom playlist from your library where you can specify the BPM (beats per minute) to
#fit your run.  The constant BPM option will contain songs with similar BPM's that reflect the given
#peak intensity, whereas selecting "no" to constant BPM will create a playlist that gradually increases
#to peak BPM and falls for the cooldown

#When prompted for "code after redirect URI," a google.com popup will appear.
#In the URL, there will be a long string of characters after "code="
#Copy and paste the entire string from the first character after the "="
#to the end of the URL

# %%
import requests
import json
import base64
import datetime
from urllib.parse import urlencode
import webbrowser
import pandas as pd
import math

# %%
class SpotifyAPI(object):
    client_id = None
    client_secret = None
    redirect = 'http://google.com/'
    client_creds_b64 = None
    
    def __init__(self, client_id, client_secret, user_id):
        self.client_id = client_id
        self.client_secret = client_secret
        self.user_id = user_id
        
        #formats client and secret client in b64 to use for authentication
        client_creds = f"{client_id}:{client_secret}"
        self.client_creds_b64 = base64.b64encode(client_creds.encode())
        self.client_creds_b64 = self.client_creds_b64.decode()
    
    #requires: scope found in the spotify API documentation
    #modifies:
    #effects: returns the access token
    def authorize_account(self, scope):
        #opens a link to log in and get the code for authentication
        url = 'https://accounts.spotify.com/authorize'
        data = urlencode({"client_id": self.client_id, 'response_type': 'code',  "redirect_uri": self.redirect,
                        "scope": scope})
        full_url = f"{url}?{data}"
        webbrowser.open(full_url)
        
        #input code from user (hopefully will be able to automate this)
        codeURL = input("Input code found after the redirect URI: ")
        token_url = 'https://accounts.spotify.com/api/token'
        headers = {
            "Authorization": f"Basic {self.client_creds_b64}"
        }

        token_data = {"grant_type": "authorization_code",
                     "code": codeURL,
                     "redirect_uri": self.redirect}
        
        r2 = requests.post(token_url, data = token_data, headers = headers)
        
        return r2
    
    #effects: returns access token that modifies playlists
    def authorize_playlist(self):
        return self.authorize_account('playlist-modify-public')
    
    #effects: returns access token to look at user library
    def authorize_library(self):
        return self.authorize_account('user-library-read')
    
    #effects: returns an access token that can't modify account in any way
    def basic_authorization(self):
        token_url = 'https://accounts.spotify.com/api/token'
        token_data = {
                    "grant_type": "client_credentials"
                }

        token_header = {
                    "Authorization": f"Basic {self.client_creds_b64}"
                }
        r2 = requests.post(token_url, data = token_data, headers = token_header)
        return r2
    
    #requires: a request object with a library access token
    #effects: returns a dictionary of liked songs
    def liked_songs(self, r2):
        
        #populates a dictionary of liked songs
        tempoDict = {}
        numSongsInLib = input("Number of songs in library: ")
        numSongsInLib = int(numSongsInLib)
        offset = 0
        limit = 50

        while(len(tempoDict) < numSongsInLib):
            query = "https://api.spotify.com/v1/users/{}/tracks".format(
                user_id)

            data = urlencode({"limit": limit, 'offset': offset})

            response = requests.get(
                f"{query}?{data}",
                headers={
                    "Content-Type": "application/json",
                    "Authorization": "Bearer {}".format(r2.json()['access_token'])
                }
            )
            tracks = response.json()

            for i in range(0, limit):
                if(len(tempoDict) == numSongsInLib):
                    break

                tempoDict[tracks['items'][i]['track']['id']] = 0

            offset += 50
        
        return tempoDict
    
    #requires: a dictionary with song IDs and a request object with a regular access token
    #effects: returns a populated dictionary with tempos
    def tempo_dictionary(self, tempoDict, r2):
        
        for i in tempoDict:
            query = "https://api.spotify.com/v1/audio-features/{}/".format(str(i))
            response = requests.get(
                query,
                headers={
                    "Authorization": "Bearer {}".format(r2.json()['access_token'])
                }
            )
            tempoDict[i] = response.json()['tempo']
            
        return tempoDict
    
    #requires a dictionary with tempos in it
    def segment_songs_by_tempo(self, tempoDict):
        
        tempoDF = pd.DataFrame(tempoDict.items(), columns = ['songID', 'tempo'])
        tempoDF = tempoDF.set_index(['songID'])
        
        df140 = tempoDF[(tempoDF['tempo'] > 140) & (tempoDF['tempo'] < 145)]
        df145 = tempoDF[(tempoDF['tempo'] > 145) & (tempoDF['tempo'] < 150)]
        df150 = tempoDF[(tempoDF['tempo'] > 150) & (tempoDF['tempo'] < 155)]
        df155 = tempoDF[(tempoDF['tempo'] > 155) & (tempoDF['tempo'] < 160)]
        df160 = tempoDF[(tempoDF['tempo'] > 160) & (tempoDF['tempo'] < 165)]
        df165 = tempoDF[(tempoDF['tempo'] > 165) & (tempoDF['tempo'] < 170)]
        df170 = tempoDF[(tempoDF['tempo'] > 170) & (tempoDF['tempo'] < 175)]
        df175 = tempoDF[(tempoDF['tempo'] > 175) & (tempoDF['tempo'] < 180)]
        df180 = tempoDF[(tempoDF['tempo'] > 180) & (tempoDF['tempo'] < 185)]
        
        dfList = [df140, df145, df150, df155, df160, df165, df170, df175, df180]
        
        return dfList
    
    #requires: list of dataframes that are segmented by tempo
    def select_songs_by_tempo(self, dfList):
        
        lenRun = input("length of run (in minutes): ")
        lenRun = int(lenRun)
        intensity = input("Peak intensity of run (scale from 1 to 8): ")
        intensity = int(intensity)
        crestBool = input("Constant BPM (y/n)?: ")
        numSongs = math.ceil(lenRun / 3.5)
        
        bagOfSongsAsc = []
        if(crestBool == 'n'):
            listInd = 0
            for i in range(0, numSongs):
                #makes sure array is inbounds
                if(listInd > 8):
                    listInd = 8
                if(listInd < 0):
                    listInd = 0
                #increments/decrements which intensity bucket the next song will be from    
                if (i < (numSongs / 2)):
                    bagOfSongsAsc.append(dfList[round(listInd)].sample())
                    listInd += (intensity - 1)/ (((numSongs - 3) / 2) + 1)
                else:
                    bagOfSongsAsc.append(dfList[math.ceil(listInd)].sample())
                    listInd -= (intensity - 1)/ (((numSongs - 3) / 2) + 1)

        else:
            for i in range(0, numSongs):
                bagOfSongsAsc.append(dfList[intensity - 1].sample())
                
        #takes only the song ID's
        bagOfID = []
        for i in bagOfSongsAsc:
            bagOfID.append(i.index.tolist()[0])
        #concatenates a string to make ID's to URI's    
        tempBagOfID = []
        for i in bagOfID:
            i = str(i)
            temp = 'spotify:track:' + i
            tempBagOfID.append(temp)
        
        return tempBagOfID
    
    #requires: a request with a modifies playlist access token
    #effects: makes a new playlist on spotify and returns the playlist ID
    def make_new_playlist(self, r2):
        playlistName = input("Playlist Name: ")

        request_body = json.dumps({
            "name": playlistName,
            "description": "Running BPM",
            "public": True
        })

        query = "https://api.spotify.com/v1/users/{}/playlists".format(
            user_id)
        response = requests.post(
            query,
            data=request_body,
            headers={
                "Content-Type": "application/json",
                "Authorization": "Bearer {}".format(r2.json()['access_token'])
            }
        )

        return response.json()['id']
    
    #requires: playlist ID, list of songs to be added, and an access token that can modify playlists
    def populate_playlist(self, playlistID, bagOfID, r2):
        
        request_body = json.dumps({
            "uris": bagOfID
        })

        query = "https://api.spotify.com/v1/playlists/{}/tracks".format(
            playlistID)
        response = requests.post(
            query,
            data=request_body,
            headers={
                "Content-Type": "application/json",
                "Authorization": "Bearer {}".format(r2.json()['access_token'])
            }
        )
        return
    
    def tempo_main(self):
        lib_token = self.authorize_library()
        client_token = self.basic_authorization()
        playlist_token = self.authorize_playlist()
        
        songs_list = self.select_songs_by_tempo(self.segment_songs_by_tempo(\
            self.tempo_dictionary(\
                self.liked_songs(lib_token), client_token)))
        
        playlist_id = self.make_new_playlist(playlist_token)
        self.populate_playlist(playlist_id, songs_list, playlist_token)
        
        return

# %%
clientID = '92b5a2e1c39246a685c140ba257f19f5'
client_secret = 'd066cb0c77c440f5a6e270d8e19cde22'
user_id = input("Input spotify userID: ")
# Out:
# Input spotify userID: jackmu4

# %%
spot = SpotifyAPI(clientID, client_secret, user_id)

# %%
spot.tempo_main()
# Out:
# Input code found after the redirect URI: AQBSTGFZAZowxcboH35Iq65xLaZ7PhHEBk1CFPuFRI26pBP-Yvw9MC-P1Q1IR1Ntx-GPBzoQiAwRc-jjsW6r92pmpGo7AKitkGcNzjuR9xEvbZcFQtJidJG4pLyV7z2ZDC4BKV2rksUig7g-Vo1wAhYh4XPY9naJ69VEQKLP_osD9OMId7GBx7o
# Input code found after the redirect URI: AQDnYVmFDzYfljaW3u9aV4GqMvoyzDmMe6YCrKBkIvZ8ans6hJ3r3OMbBhoQtys5xIaESwGnBCCKX_w-jbXLQHgn9rMyF5zo6hAloCvdcvbkl95FeEMpNO_Cv0UI6z6pvrnyDJJT4PMMFTZBOH_uGzgpOlHTPNauziTVxh7hIbHhtfCQva-eUTwh9nk90g
# Number of songs in library: 1845

# %% [markdown]
# # Testing Site

# %%
numSongs = 10
intensity = 3
listInd = 0.0

for i in range(0, numSongs):
    #makes sure array is inbounds
    if(listInd > 8):
        listInd = 8.0
    if(listInd < 0):
        listInd = 0.0
    #increments/decrements which intensity bucket the next song will be from    
    if (i < (numSongs / 2)):
        print(round(listInd), ' + ', (intensity - 1) / (((numSongs - 3) / 2) + 1))
        listInd += (intensity - 1)/ (((numSongs - 3) / 2) + 1)
    else:
        print(math.ceil(listInd), ' - ', (intensity - 1) / (((numSongs - 3) / 2) + 1))
        listInd -= (intensity - 1) / (((numSongs - 3) / 2) + 1)
# Out:
# 0  +  0.4444444444444444
# 0  +  0.4444444444444444
# 1  +  0.4444444444444444
# 1  +  0.4444444444444444
# 2  +  0.4444444444444444
# 3  -  0.4444444444444444
# 2  -  0.4444444444444444
# 2  -  0.4444444444444444
# 1  -  0.4444444444444444
# 1  -  0.4444444444444444

# %%
lib_token = spot.authorize_library()
# Out:
# Input code found after the redirect URI: AQBHJ7gt9-4hY_oP9TdAkWYi89EBXknXPYVpo2K4JNVxPotCxt6Dy1dxiEV5Vdtkq5BaZ9l61HERrvxPtquASorf3I0cWo0k8Pk5f4u5-Ez_AZe2zQpUeIo5EbAeDrC34fg-dcq4Coj1hoNEaY9BGwiLL82_Q-xaw6Um-dlg3MGVnBWf3WT02Xo

# %%
limit = 50
offset = 150
query = "https://api.spotify.com/v1/users/{}/tracks".format(
                user_id)

data = urlencode({"limit": limit, 'offset': offset})

response = requests.get(
    f"{query}?{data}",
    headers={
        "Content-Type": "application/json",
        "Authorization": "Bearer {}".format(lib_token.json()['access_token'])
    }
)
tracks = response.json()

tracks
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=150&limit=50',
#  'items': [{'added_at': '2020-03-12T16:52:41Z',
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Jeckitay8SbvKwqAzWuYH'},
#        'href': 'https://api.spotify.com/v1/artists/0Jeckitay8SbvKwqAzWuYH',
#        'id': '0Jeckitay8SbvKwqAzWuYH',
#        'name': 'Big Mountain',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Jeckitay8SbvKwqAzWuYH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QHFXQLRwZx5122InHluo5'},
#      'href': 'https://api.spotify.com/v1/albums/4QHFXQLRwZx5122InHluo5',
#      'id': '4QHFXQLRwZx5122InHluo5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738dad961673a82ade27f202a8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028dad961673a82ade27f202a8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518dad961673a82ade27f202a8',
#        'width': 64}],
#      'name': 'The Best Of Big Mountain',
#      'release_date': '1994',
#      'release_date_precision': 'year',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4QHFXQLRwZx5122InHluo5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Jeckitay8SbvKwqAzWuYH'},
#       'href': 'https://api.spotify.com/v1/artists/0Jeckitay8SbvKwqAzWuYH',
#       'id': '0Jeckitay8SbvKwqAzWuYH',
#       'name': 'Big Mountain',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Jeckitay8SbvKwqAzWuYH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/32ckuKo8LrZhQMyCehYKkt'},
#       'href': 'https://api.spotify.com/v1/artists/32ckuKo8LrZhQMyCehYKkt',
#       'id': '32ckuKo8LrZhQMyCehYKkt',
#       'name': 'Tom Lord-Alge',
#       'type': 'artist',
#       'uri': 'spotify:artist:32ckuKo8LrZhQMyCehYKkt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 249520,
#     'explicit': False,
#     'external_ids': {'isrc': 'USGI19400026'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Rvl8qsKJurfFTyWLBI9ib'},
#     'href': 'https://api.spotify.com/v1/tracks/1Rvl8qsKJurfFTyWLBI9ib',
#     'id': '1Rvl8qsKJurfFTyWLBI9ib',
#     'is_local': False,
#     'name': 'Baby, I Love Your Way',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2088ffea2a54124e1e4e5e195303251f401c796f?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Rvl8qsKJurfFTyWLBI9ib'}},
#   {'added_at': '2020-03-12T15:56:55Z',
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qbnxnvUqR14MJ9g8QwZJK'},
#        'href': 'https://api.spotify.com/v1/artists/3qbnxnvUqR14MJ9g8QwZJK',
#        'id': '3qbnxnvUqR14MJ9g8QwZJK',
#        'name': 'Lonestar',
#        'type': 'artist',
#        'uri': 'spotify:artist:3qbnxnvUqR14MJ9g8QwZJK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2JZvVC4RftWDbyhEFfpATZ'},
#      'href': 'https://api.spotify.com/v1/albums/2JZvVC4RftWDbyhEFfpATZ',
#      'id': '2JZvVC4RftWDbyhEFfpATZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a2d341e4e11f00efddf8115',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a2d341e4e11f00efddf8115',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a2d341e4e11f00efddf8115',
#        'width': 64}],
#      'name': '16 Biggest Hits',
#      'release_date': '1995',
#      'release_date_precision': 'year',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2JZvVC4RftWDbyhEFfpATZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qbnxnvUqR14MJ9g8QwZJK'},
#       'href': 'https://api.spotify.com/v1/artists/3qbnxnvUqR14MJ9g8QwZJK',
#       'id': '3qbnxnvUqR14MJ9g8QwZJK',
#       'name': 'Lonestar',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qbnxnvUqR14MJ9g8QwZJK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 240000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBN19800111'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5oQx6XZyrOOkGbme8DA9GO'},
#     'href': 'https://api.spotify.com/v1/tracks/5oQx6XZyrOOkGbme8DA9GO',
#     'id': '5oQx6XZyrOOkGbme8DA9GO',
#     'is_local': False,
#     'name': 'Amazed',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2aa5edf85faa02576576b5d2464fee5c4480ec25?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5oQx6XZyrOOkGbme8DA9GO'}},
#   {'added_at': '2020-03-12T15:41:54Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Va9LuEmaZxnbk1gMnjMD7'},
#        'href': 'https://api.spotify.com/v1/artists/5Va9LuEmaZxnbk1gMnjMD7',
#        'id': '5Va9LuEmaZxnbk1gMnjMD7',
#        'name': 'Arrested Development',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Va9LuEmaZxnbk1gMnjMD7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3b8DtdLKq4oD6e1DLQUgBU'},
#      'href': 'https://api.spotify.com/v1/albums/3b8DtdLKq4oD6e1DLQUgBU',
#      'id': '3b8DtdLKq4oD6e1DLQUgBU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273332f50e07727cc29d6f1f6ae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02332f50e07727cc29d6f1f6ae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851332f50e07727cc29d6f1f6ae',
#        'width': 64}],
#      'name': 'Extended Revolution',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3b8DtdLKq4oD6e1DLQUgBU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Va9LuEmaZxnbk1gMnjMD7'},
#       'href': 'https://api.spotify.com/v1/artists/5Va9LuEmaZxnbk1gMnjMD7',
#       'id': '5Va9LuEmaZxnbk1gMnjMD7',
#       'name': 'Arrested Development',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Va9LuEmaZxnbk1gMnjMD7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 298773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCH39200012'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1nSUJWYRqsafI8Bh1X0ypp'},
#     'href': 'https://api.spotify.com/v1/tracks/1nSUJWYRqsafI8Bh1X0ypp',
#     'id': '1nSUJWYRqsafI8Bh1X0ypp',
#     'is_local': False,
#     'name': 'People Everyday',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a0353b5c6451b3dd8f54e69e01487e0364a5c4ad?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1nSUJWYRqsafI8Bh1X0ypp'}},
#   {'added_at': '2020-03-11T13:42:40Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6O74knDqdv3XaWtkII7Xjp'},
#        'href': 'https://api.spotify.com/v1/artists/6O74knDqdv3XaWtkII7Xjp',
#        'id': '6O74knDqdv3XaWtkII7Xjp',
#        'name': 'Boyz II Men',
#        'type': 'artist',
#        'uri': 'spotify:artist:6O74knDqdv3XaWtkII7Xjp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jknvlUSe6D9Oyn2E3JBLO'},
#      'href': 'https://api.spotify.com/v1/albums/3jknvlUSe6D9Oyn2E3JBLO',
#      'id': '3jknvlUSe6D9Oyn2E3JBLO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27373d0d8625dcf1e48043cfbf9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0273d0d8625dcf1e48043cfbf9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485173d0d8625dcf1e48043cfbf9',
#        'width': 64}],
#      'name': 'Cooleyhighharmony (Bonus Tracks Version)',
#      'release_date': '1991-04-30',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:3jknvlUSe6D9Oyn2E3JBLO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6O74knDqdv3XaWtkII7Xjp'},
#       'href': 'https://api.spotify.com/v1/artists/6O74knDqdv3XaWtkII7Xjp',
#       'id': '6O74knDqdv3XaWtkII7Xjp',
#       'name': 'Boyz II Men',
#       'type': 'artist',
#       'uri': 'spotify:artist:6O74knDqdv3XaWtkII7Xjp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 351466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO19200465'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3l3xTXsUXeWlkPqzMs7mPD'},
#     'href': 'https://api.spotify.com/v1/tracks/3l3xTXsUXeWlkPqzMs7mPD',
#     'id': '3l3xTXsUXeWlkPqzMs7mPD',
#     'is_local': False,
#     'name': 'End Of The Road',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1e4b116769eccc2818f4f7614508d4b7fdb08f4?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:3l3xTXsUXeWlkPqzMs7mPD'}},
#   {'added_at': '2020-03-11T13:04:58Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Hizgjo92FnMp8wGaRUNTn'},
#        'href': 'https://api.spotify.com/v1/artists/6Hizgjo92FnMp8wGaRUNTn',
#        'id': '6Hizgjo92FnMp8wGaRUNTn',
#        'name': 'Vertical Horizon',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Hizgjo92FnMp8wGaRUNTn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2gJ6axVHAsQmmO6nslQRN1'},
#      'href': 'https://api.spotify.com/v1/albums/2gJ6axVHAsQmmO6nslQRN1',
#      'id': '2gJ6axVHAsQmmO6nslQRN1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730858a3cb541f3edcc4ea0f00',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020858a3cb541f3edcc4ea0f00',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510858a3cb541f3edcc4ea0f00',
#        'width': 64}],
#      'name': 'Everything You Want',
#      'release_date': '1999-06-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2gJ6axVHAsQmmO6nslQRN1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Hizgjo92FnMp8wGaRUNTn'},
#       'href': 'https://api.spotify.com/v1/artists/6Hizgjo92FnMp8wGaRUNTn',
#       'id': '6Hizgjo92FnMp8wGaRUNTn',
#       'name': 'Vertical Horizon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Hizgjo92FnMp8wGaRUNTn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 257066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC19900048'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4cKGldbhGJniI8BrB3K6tb'},
#     'href': 'https://api.spotify.com/v1/tracks/4cKGldbhGJniI8BrB3K6tb',
#     'id': '4cKGldbhGJniI8BrB3K6tb',
#     'is_local': False,
#     'name': 'Everything You Want',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1fdf25d61b20eefe08ad2ed6d1c9cdab497ad36f?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4cKGldbhGJniI8BrB3K6tb'}},
#   {'added_at': '2020-03-11T12:56:49Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FbDoZnMBTdhhhLuJBOOqP'},
#        'href': 'https://api.spotify.com/v1/artists/6FbDoZnMBTdhhhLuJBOOqP',
#        'id': '6FbDoZnMBTdhhhLuJBOOqP',
#        'name': 'Jewel',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FbDoZnMBTdhhhLuJBOOqP'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6t0qVXx77kMCVyxHejzJsP'},
#      'href': 'https://api.spotify.com/v1/albums/6t0qVXx77kMCVyxHejzJsP',
#      'id': '6t0qVXx77kMCVyxHejzJsP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733ee723db532524d6a22d26af',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023ee723db532524d6a22d26af',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513ee723db532524d6a22d26af',
#        'width': 64}],
#      'name': 'Pieces Of You',
#      'release_date': '1995',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6t0qVXx77kMCVyxHejzJsP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FbDoZnMBTdhhhLuJBOOqP'},
#       'href': 'https://api.spotify.com/v1/artists/6FbDoZnMBTdhhhLuJBOOqP',
#       'id': '6FbDoZnMBTdhhhLuJBOOqP',
#       'name': 'Jewel',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FbDoZnMBTdhhhLuJBOOqP'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 254480,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT20100948'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6kBU9uWqar0Fw2Ws0he11A'},
#     'href': 'https://api.spotify.com/v1/tracks/6kBU9uWqar0Fw2Ws0he11A',
#     'id': '6kBU9uWqar0Fw2Ws0he11A',
#     'is_local': False,
#     'name': 'You Were Meant For Me',
#     'popularity': 1,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:6kBU9uWqar0Fw2Ws0he11A'}},
#   {'added_at': '2020-03-11T12:32:41Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37w38cCSGgKLdayTRjna4W'},
#        'href': 'https://api.spotify.com/v1/artists/37w38cCSGgKLdayTRjna4W',
#        'id': '37w38cCSGgKLdayTRjna4W',
#        'name': 'Mazzy Star',
#        'type': 'artist',
#        'uri': 'spotify:artist:37w38cCSGgKLdayTRjna4W'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5K18gTgac0q6Jma5HkV1vA'},
#      'href': 'https://api.spotify.com/v1/albums/5K18gTgac0q6Jma5HkV1vA',
#      'id': '5K18gTgac0q6Jma5HkV1vA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389a392107ebd79818022b3ea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289a392107ebd79818022b3ea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189a392107ebd79818022b3ea',
#        'width': 64}],
#      'name': 'So Tonight That I Might See',
#      'release_date': '1993-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5K18gTgac0q6Jma5HkV1vA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37w38cCSGgKLdayTRjna4W'},
#       'href': 'https://api.spotify.com/v1/artists/37w38cCSGgKLdayTRjna4W',
#       'id': '37w38cCSGgKLdayTRjna4W',
#       'name': 'Mazzy Star',
#       'type': 'artist',
#       'uri': 'spotify:artist:37w38cCSGgKLdayTRjna4W'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 295600,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29300105'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1LzNfuep1bnAUR9skqdHCK'},
#     'href': 'https://api.spotify.com/v1/tracks/1LzNfuep1bnAUR9skqdHCK',
#     'id': '1LzNfuep1bnAUR9skqdHCK',
#     'is_local': False,
#     'name': 'Fade Into You',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/65efceac3138c854ad19fb77ceee9502e58f0b58?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1LzNfuep1bnAUR9skqdHCK'}},
#   {'added_at': '2020-03-11T12:32:13Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#        'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#        'id': '2sil8z5kiy4r76CRTXxBCA',
#        'name': 'The Goo Goo Dolls',
#        'type': 'artist',
#        'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#      'href': 'https://api.spotify.com/v1/albums/4UMjBXcRqIgMZ1XumU2x5T',
#      'id': '4UMjBXcRqIgMZ1XumU2x5T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eda9478c39a21e1cdc6609ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eda9478c39a21e1cdc6609ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eda9478c39a21e1cdc6609ca',
#        'width': 64}],
#      'name': 'Dizzy up the Girl',
#      'release_date': '1998-09-11',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4UMjBXcRqIgMZ1XumU2x5T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#       'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#       'id': '2sil8z5kiy4r76CRTXxBCA',
#       'name': 'The Goo Goo Dolls',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB19800781'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0nnwn7LWHCAu09jfuH1xTA'},
#     'href': 'https://api.spotify.com/v1/tracks/0nnwn7LWHCAu09jfuH1xTA',
#     'id': '0nnwn7LWHCAu09jfuH1xTA',
#     'is_local': False,
#     'name': 'Slide',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/28cc4f1970ab4dfa3ed97b98ce801e884584a321?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0nnwn7LWHCAu09jfuH1xTA'}},
#   {'added_at': '2020-03-11T12:31:56Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ngh2zDBRPEriyxQDAMKd1'},
#        'href': 'https://api.spotify.com/v1/artists/3Ngh2zDBRPEriyxQDAMKd1',
#        'id': '3Ngh2zDBRPEriyxQDAMKd1',
#        'name': 'Matchbox Twenty',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Ngh2zDBRPEriyxQDAMKd1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vUXTcKz7tXxrNl84meN6i'},
#      'href': 'https://api.spotify.com/v1/albums/4vUXTcKz7tXxrNl84meN6i',
#      'id': '4vUXTcKz7tXxrNl84meN6i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27323dbfb8b3b1be429587f5380',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0223dbfb8b3b1be429587f5380',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485123dbfb8b3b1be429587f5380',
#        'width': 64}],
#      'name': 'Yourself or Someone Like You',
#      'release_date': '1996-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4vUXTcKz7tXxrNl84meN6i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ngh2zDBRPEriyxQDAMKd1'},
#       'href': 'https://api.spotify.com/v1/artists/3Ngh2zDBRPEriyxQDAMKd1',
#       'id': '3Ngh2zDBRPEriyxQDAMKd1',
#       'name': 'Matchbox Twenty',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Ngh2zDBRPEriyxQDAMKd1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 225946,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT29600038'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5vYA1mW9g2Coh1HUFUSmlb'},
#     'href': 'https://api.spotify.com/v1/tracks/5vYA1mW9g2Coh1HUFUSmlb',
#     'id': '5vYA1mW9g2Coh1HUFUSmlb',
#     'is_local': False,
#     'name': '3AM',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cb68c9ae8925bb3fc45544e5f21de17df18b957d?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5vYA1mW9g2Coh1HUFUSmlb'}},
#   {'added_at': '2020-03-11T12:28:00Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KEb1kbIZN5jumsjFEWgSW'},
#        'href': 'https://api.spotify.com/v1/artists/3KEb1kbIZN5jumsjFEWgSW',
#        'id': '3KEb1kbIZN5jumsjFEWgSW',
#        'name': 'Tal Bachman',
#        'type': 'artist',
#        'uri': 'spotify:artist:3KEb1kbIZN5jumsjFEWgSW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3v17hBg9lx5vdJQ8Dfr6OD'},
#      'href': 'https://api.spotify.com/v1/albums/3v17hBg9lx5vdJQ8Dfr6OD',
#      'id': '3v17hBg9lx5vdJQ8Dfr6OD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f875c8285d7f26a42baaa2a0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f875c8285d7f26a42baaa2a0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f875c8285d7f26a42baaa2a0',
#        'width': 64}],
#      'name': 'Tal Bachman',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3v17hBg9lx5vdJQ8Dfr6OD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KEb1kbIZN5jumsjFEWgSW'},
#       'href': 'https://api.spotify.com/v1/artists/3KEb1kbIZN5jumsjFEWgSW',
#       'id': '3KEb1kbIZN5jumsjFEWgSW',
#       'name': 'Tal Bachman',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KEb1kbIZN5jumsjFEWgSW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19802720'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7mnGQesk1TzQLzQ9bYWZPR'},
#     'href': 'https://api.spotify.com/v1/tracks/7mnGQesk1TzQLzQ9bYWZPR',
#     'id': '7mnGQesk1TzQLzQ9bYWZPR',
#     'is_local': False,
#     'name': "She's so High",
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4554c4f666f713acc1508fdd8f24c709f21e5fe8?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7mnGQesk1TzQLzQ9bYWZPR'}},
#   {'added_at': '2020-03-11T02:17:10Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZfHkwHuoAZrlz7RMj0PDz'},
#      'href': 'https://api.spotify.com/v1/albums/2ZfHkwHuoAZrlz7RMj0PDz',
#      'id': '2ZfHkwHuoAZrlz7RMj0PDz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c464fabb4e51b72d657f779a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c464fabb4e51b72d657f779a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c464fabb4e51b72d657f779a',
#        'width': 64}],
#      'name': 'Blinding Lights',
#      'release_date': '2019-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2ZfHkwHuoAZrlz7RMj0PDz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 201573,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11904206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0sf12qNH5qcw8qpgymFOqD'},
#     'href': 'https://api.spotify.com/v1/tracks/0sf12qNH5qcw8qpgymFOqD',
#     'id': '0sf12qNH5qcw8qpgymFOqD',
#     'is_local': False,
#     'name': 'Blinding Lights',
#     'popularity': 50,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0sf12qNH5qcw8qpgymFOqD'}},
#   {'added_at': '2020-03-10T20:42:56Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QkgnHpxSCOYdTnhUR9S5k'},
#        'href': 'https://api.spotify.com/v1/artists/0QkgnHpxSCOYdTnhUR9S5k',
#        'id': '0QkgnHpxSCOYdTnhUR9S5k',
#        'name': 'RIZ LA VIE',
#        'type': 'artist',
#        'uri': 'spotify:artist:0QkgnHpxSCOYdTnhUR9S5k'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6YWUNw1FYlbjBwLEeqqt8Y'},
#      'href': 'https://api.spotify.com/v1/albums/6YWUNw1FYlbjBwLEeqqt8Y',
#      'id': '6YWUNw1FYlbjBwLEeqqt8Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273363c8acf6c17ca3fe92e07f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02363c8acf6c17ca3fe92e07f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851363c8acf6c17ca3fe92e07f6',
#        'width': 64}],
#      'name': 'Saturn',
#      'release_date': '2019-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6YWUNw1FYlbjBwLEeqqt8Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QkgnHpxSCOYdTnhUR9S5k'},
#       'href': 'https://api.spotify.com/v1/artists/0QkgnHpxSCOYdTnhUR9S5k',
#       'id': '0QkgnHpxSCOYdTnhUR9S5k',
#       'name': 'RIZ LA VIE',
#       'type': 'artist',
#       'uri': 'spotify:artist:0QkgnHpxSCOYdTnhUR9S5k'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 207719,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBKPL1954251'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6WY88gYhRrnqS4wGtO45TH'},
#     'href': 'https://api.spotify.com/v1/tracks/6WY88gYhRrnqS4wGtO45TH',
#     'id': '6WY88gYhRrnqS4wGtO45TH',
#     'is_local': False,
#     'name': 'Saturn',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/23a49f198ec48cecc46880c82cd00e8c084b6083?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6WY88gYhRrnqS4wGtO45TH'}},
#   {'added_at': '2020-03-09T21:57:52Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5PxCTrv3Y1xVACfngpt7D2'},
#        'href': 'https://api.spotify.com/v1/artists/5PxCTrv3Y1xVACfngpt7D2',
# ...
#       'href': 'https://api.spotify.com/v1/artists/0JWCunuoONu5hea71f2a2H',
#       'id': '0JWCunuoONu5hea71f2a2H',
#       'name': 'Caroline Ailin',
#       'type': 'artist',
#       'uri': 'spotify:artist:0JWCunuoONu5hea71f2a2H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 180147,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71713350'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4v0134PgBTGsFJiGcV4eJk'},
#     'href': 'https://api.spotify.com/v1/tracks/4v0134PgBTGsFJiGcV4eJk',
#     'id': '4v0134PgBTGsFJiGcV4eJk',
#     'is_local': False,
#     'name': 'Last To Leave (feat. Caroline Ailin)',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cdfb7fe6979797795e4f06179eaf8ef2b78e42be?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4v0134PgBTGsFJiGcV4eJk'}},
#   {'added_at': '2020-02-25T04:40:14Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#        'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#        'id': '7wg1qvie3KqDNQbAkTdbX0',
#        'name': 'Louis The Child',
#        'type': 'artist',
#        'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/76yeOnINtQSXyoEHbkYmtY'},
#        'href': 'https://api.spotify.com/v1/artists/76yeOnINtQSXyoEHbkYmtY',
#        'id': '76yeOnINtQSXyoEHbkYmtY',
#        'name': 'Drew Love',
#        'type': 'artist',
#        'uri': 'spotify:artist:76yeOnINtQSXyoEHbkYmtY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vPi417GIyreDLamFQVZJd'},
#      'href': 'https://api.spotify.com/v1/albums/4vPi417GIyreDLamFQVZJd',
#      'id': '4vPi417GIyreDLamFQVZJd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f32af31fa8b8e5af33860ee7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f32af31fa8b8e5af33860ee7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f32af31fa8b8e5af33860ee7',
#        'width': 64}],
#      'name': 'Free (with Drew Love)',
#      'release_date': '2019-11-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4vPi417GIyreDLamFQVZJd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#       'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#       'id': '7wg1qvie3KqDNQbAkTdbX0',
#       'name': 'Louis The Child',
#       'type': 'artist',
#       'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/76yeOnINtQSXyoEHbkYmtY'},
#       'href': 'https://api.spotify.com/v1/artists/76yeOnINtQSXyoEHbkYmtY',
#       'id': '76yeOnINtQSXyoEHbkYmtY',
#       'name': 'Drew Love',
#       'type': 'artist',
#       'uri': 'spotify:artist:76yeOnINtQSXyoEHbkYmtY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 222252,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71922041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64BKKgWdKdmKlQDzRfHW3C'},
#     'href': 'https://api.spotify.com/v1/tracks/64BKKgWdKdmKlQDzRfHW3C',
#     'id': '64BKKgWdKdmKlQDzRfHW3C',
#     'is_local': False,
#     'name': 'Free (with Drew Love)',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a9aa0c4ab5c5957c14bcce71e56c8d4fa9339c0d?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:64BKKgWdKdmKlQDzRfHW3C'}},
#   {'added_at': '2020-02-25T04:39:09Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#        'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#        'id': '7wg1qvie3KqDNQbAkTdbX0',
#        'name': 'Louis The Child',
#        'type': 'artist',
#        'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/21R2CiMVZH2MY514Sq2DIG'},
#      'href': 'https://api.spotify.com/v1/albums/21R2CiMVZH2MY514Sq2DIG',
#      'id': '21R2CiMVZH2MY514Sq2DIG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27353c069027efd7447798e844d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0253c069027efd7447798e844d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485153c069027efd7447798e844d',
#        'width': 64}],
#      'name': 'Kids At Play- EP',
#      'release_date': '2018-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:21R2CiMVZH2MY514Sq2DIG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7wg1qvie3KqDNQbAkTdbX0'},
#       'href': 'https://api.spotify.com/v1/artists/7wg1qvie3KqDNQbAkTdbX0',
#       'id': '7wg1qvie3KqDNQbAkTdbX0',
#       'name': 'Louis The Child',
#       'type': 'artist',
#       'uri': 'spotify:artist:7wg1qvie3KqDNQbAkTdbX0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0FL2d6iFFNAV3yBUbXjZ1U'},
#       'href': 'https://api.spotify.com/v1/artists/0FL2d6iFFNAV3yBUbXjZ1U',
#       'id': '0FL2d6iFFNAV3yBUbXjZ1U',
#       'name': 'Wafia',
#       'type': 'artist',
#       'uri': 'spotify:artist:0FL2d6iFFNAV3yBUbXjZ1U'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 222865,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71804511'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7n1940b6kHcaEewFSZXnXa'},
#     'href': 'https://api.spotify.com/v1/tracks/7n1940b6kHcaEewFSZXnXa',
#     'id': '7n1940b6kHcaEewFSZXnXa',
#     'is_local': False,
#     'name': 'Better Not (with Wafia)',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3c656ff707944c66809aaa264465a9a2aeb84de1?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7n1940b6kHcaEewFSZXnXa'}},
#   {'added_at': '2020-02-23T23:54:54Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#        'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#        'id': '6l3HvQ5sa6mXTsMTB19rO5',
#        'name': 'J. Cole',
#        'type': 'artist',
#        'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3XzSOIE6zGLliuqsVGLmUc'},
#      'href': 'https://api.spotify.com/v1/albums/3XzSOIE6zGLliuqsVGLmUc',
#      'id': '3XzSOIE6zGLliuqsVGLmUc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f37a4001ae7d8be430bd91b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f37a4001ae7d8be430bd91b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f37a4001ae7d8be430bd91b',
#        'width': 64}],
#      'name': 'MIDDLE CHILD',
#      'release_date': '2019-01-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3XzSOIE6zGLliuqsVGLmUc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#       'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#       'id': '6l3HvQ5sa6mXTsMTB19rO5',
#       'name': 'J. Cole',
#       'type': 'artist',
#       'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213593,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMJMT1902056'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2JvzF1RMd7lE3KmFlsyZD8'},
#     'href': 'https://api.spotify.com/v1/tracks/2JvzF1RMd7lE3KmFlsyZD8',
#     'id': '2JvzF1RMd7lE3KmFlsyZD8',
#     'is_local': False,
#     'name': 'MIDDLE CHILD',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e4492a8e947867f465309e9ae70565513f50eb82?cid=92b5a2e1c39246a685c140ba257f19f5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2JvzF1RMd7lE3KmFlsyZD8'}}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/me/tracks?offset=200&limit=50',
#  'offset': 150,
#  'previous': 'https://api.spotify.com/v1/me/tracks?offset=100&limit=50',
#  'total': 1414}

# %%
tracks['items'][0]['track']
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Jeckitay8SbvKwqAzWuYH'},
#     'href': 'https://api.spotify.com/v1/artists/0Jeckitay8SbvKwqAzWuYH',
#     'id': '0Jeckitay8SbvKwqAzWuYH',
#     'name': 'Big Mountain',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Jeckitay8SbvKwqAzWuYH'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4QHFXQLRwZx5122InHluo5'},
#   'href': 'https://api.spotify.com/v1/albums/4QHFXQLRwZx5122InHluo5',
#   'id': '4QHFXQLRwZx5122InHluo5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738dad961673a82ade27f202a8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028dad961673a82ade27f202a8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518dad961673a82ade27f202a8',
#     'width': 64}],
#   'name': 'The Best Of Big Mountain',
#   'release_date': '1994',
#   'release_date_precision': 'year',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:4QHFXQLRwZx5122InHluo5'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Jeckitay8SbvKwqAzWuYH'},
#    'href': 'https://api.spotify.com/v1/artists/0Jeckitay8SbvKwqAzWuYH',
#    'id': '0Jeckitay8SbvKwqAzWuYH',
#    'name': 'Big Mountain',
#    'type': 'artist',
#    'uri': 'spotify:artist:0Jeckitay8SbvKwqAzWuYH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/32ckuKo8LrZhQMyCehYKkt'},
#    'href': 'https://api.spotify.com/v1/artists/32ckuKo8LrZhQMyCehYKkt',
#    'id': '32ckuKo8LrZhQMyCehYKkt',
#    'name': 'Tom Lord-Alge',
#    'type': 'artist',
#    'uri': 'spotify:artist:32ckuKo8LrZhQMyCehYKkt'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 249520,
#  'explicit': False,
#  'external_ids': {'isrc': 'USGI19400026'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1Rvl8qsKJurfFTyWLBI9ib'},
#  'href': 'https://api.spotify.com/v1/tracks/1Rvl8qsKJurfFTyWLBI9ib',
#  'id': '1Rvl8qsKJurfFTyWLBI9ib',
#  'is_local': False,
#  'name': 'Baby, I Love Your Way',
#  'popularity': 72,
#  'preview_url': 'https://p.scdn.co/mp3-preview/2088ffea2a54124e1e4e5e195303251f401c796f?cid=92b5a2e1c39246a685c140ba257f19f5',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:1Rvl8qsKJurfFTyWLBI9ib'}

# %%
liked_songs = spot.liked_songs(lib_token)
# Out:
# Number of songs in library: 1414

# %%
query = "https://api.spotify.com/v1/audio-features/{}/".format('1Rvl8qsKJurfFTyWLBI9ib')
response = requests.get(
    query,
    headers={
        "Authorization": "Bearer {}".format(lib_token.json()['access_token'])
    }
)
response.json()
# Out:
# {'danceability': 0.651,
#  'energy': 0.747,
#  'key': 1,
#  'loudness': -7.269,
#  'mode': 0,
#  'speechiness': 0.0699,
#  'acousticness': 0.0528,
#  'instrumentalness': 0,
#  'liveness': 0.207,
#  'valence': 0.776,
#  'tempo': 147.518,
#  'type': 'audio_features',
#  'id': '1Rvl8qsKJurfFTyWLBI9ib',
#  'uri': 'spotify:track:1Rvl8qsKJurfFTyWLBI9ib',
#  'track_href': 'https://api.spotify.com/v1/tracks/1Rvl8qsKJurfFTyWLBI9ib',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Rvl8qsKJurfFTyWLBI9ib',
#  'duration_ms': 249520,
#  'time_signature': 4}

# %%
# def select_songs_by_tempo(self, dfList):
        
#     lenRun = input("length of run (in minutes): ")
#     lenRun = int(lenRun)
#     intensity = input("Peak intensity of run (scale from 1 to 10): ")
#     intensity = int(intensity) - 1
#     crestBool = input("Constant BPM (y/n)?: ")
#     numSongs = math.ceil(lenRun / 3.5)

#     bagOfSongsAsc = []
#     if(crestBool == 'n'):
#         listInd = 0
#         for i in range(0, numSongs):
#             #makes sure array is inbounds
#             if(listInd > 8):
#                 listInd = 8
#             if(listInd < 0):
#                 listInd = 0
#             #increments/decrements which intensity bucket the next song will be from    
#             if (i < (numSongs / 2) - 1):
#                 bagOfSongsAsc.append(dfList[listInd].sample())
#                 listInd += math.ceil(intensity / math.floor(numSongs / 2))
#             else:
#                 bagOfSongsAsc.append(dfList[listInd].sample())
#                 listInd -= math.ceil(intensity / math.floor(numSongs / 2))
#     else:
#         for i in range(0, numSongs):
#             bagOfSongsAsc.append(dfList[intensity - 1].sample())
#     #takes only the song ID's
#     bagOfID = []
#     for i in bagOfSongsAsc:
#         bagOfID.append(i.index.tolist()[0])
#     #concatenates a string to make ID's to URI's    
#     tempBagOfID = []
#     for i in bagOfID:
#         i = str(i)
#         temp = 'spotify:track:' + i
#         tempBagOfID.append(temp)

#     return tempBagOfID
